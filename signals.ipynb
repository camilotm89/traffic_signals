# %%
import tensorflow as tf

# %%
x1= tf.constant([1,2,3,4,5])
x2= tf.constant([5,6,7,8,9])

# %%
res= tf.multiply(x1,x2)

# %%
print(res)
# Out:
# Tensor("Mul:0", shape=(5,), dtype=int32)

# %%
sess = tf.Session()
print(sess.run(res))
sess.close()
# Out:
# [ 5 12 21 32 45]

# %%
with tf.Session() as sess:
    output = sess.run(res)
    print(output)
# Out:
# [ 5 12 21 32 45]

# %% [markdown]
# cargamos los datos

# %%
import os
import skimage
def load_data(data_directory):
    dirs = [d for d in os.listdir(data_directory)
            if os.path.isdir(os.path.join(data_directory,d))]

    print(dirs)
    labels=[]
    images=[]
    for d in dirs:
        label_dir = os.path.join(data_directory, d)
        file_names = [os.path.join(label_dir, f)
                     for f in os.listdir(label_dir)
                     if f.endswith('.ppm')]
        print(label_dir)
        print(file_names)
        
        for f in file_names:
            images.append(skimage.io.imread(f))
            labels.append(int(d))
    return images, labels

# %%
main_dir = "signals"
train_dir = os.path.join(main_dir, "training")
test_dir = os.path.join(main_dir, "testing")

# %%
images, labels = load_data(train_dir)
# Out:
# ['00031', '00009', '00036', '00000', '00038', '00007', '00053', '00054', '00039', '00006', '00001', '00008', '00037', '00030', '00055', '00052', '00048', '00041', '00046', '00012', '00015', '00023', '00024', '00047', '00040', '00049', '00025', '00022', '00014', '00013', '00057', '00050', '00059', '00061', '00035', '00032', '00004', '00003', '00060', '00058', '00051', '00056', '00002', '00005', '00033', '00034', '00016', '00029', '00011', '00027', '00018', '00020', '00045', '00042', '00021', '00026', '00019', '00010', '00017', '00028', '00043', '00044']
# signals/training/00031
# ...

# %%
import numpy as np

# %%
labels = np.array(labels)
images = np.array(images)

# %%
import matplotlib.pyplot as plt

plt.hist(labels, len(set(labels)))
plt.show()

# %%
import random

rand_images = random.sample(range(0, len(labels)), 6)
print(rand_images)


for i in range(len(rand_images)):
    temp_im=images[rand_images[i]]
    plt.subplot(1,len(rand_images),i+1)
    plt.axis("off")
    plt.imshow(images[rand_images[i]])
    plt.show()
    print("forma: {0}, min: {1}, max: {2}".format(temp_im.shape,
                                                 temp_im.min(),
                                                 temp_im.max()))
# Out:
# [3078, 4175, 2419, 2704, 2640, 570]
# forma: (159, 159, 3), min: 0, max: 255
# forma: (177, 191, 3), min: 4, max: 255
# forma: (63, 44, 3), min: 21, max: 255
# forma: (59, 58, 3), min: 0, max: 255
# forma: (314, 122, 3), min: 0, max: 255
# forma: (99, 109, 3), min: 13, max: 187

# %%
unifique_labels=set(labels)
plt.figure(figsize=(16,16))
i=1
for label in unifique_labels:
    temp_im=images[list(labels).index(label)]
    plt.subplot(8,8, i)
    plt.axis("off")
    plt.title("clase: {0}: {1}".format(label, list(labels).count(label)))
    i=i+1
    plt.imshow(temp_im)

# %% [markdown]
# # modelo de red neuronal TF

# %%
from skimage import transform
w=999 
h=999
for image in images:
    if image.shape[0] < h:
        h = image.shape[0]
    if image.shape[1] < w:
        w = image.shape[1]
print("ancho: {0}, alto: {1}".format(w,h))
# Out:
# ancho: 20, alto: 22

# %%
# RESIZE DEL DATASET

# %%
images30 = []
for i in images:
    images30.append(transform.resize(i,(30,30)))

# %%
rand_images = random.sample(range(0, len(labels)), 6)
rand_images

for i in range(len(rand_images)):
    temp_im=images30[rand_images[i]]
    plt.subplot(1,len(rand_images),i+1)
    plt.axis("off")
    plt.imshow(images[rand_images[i]])
    plt.show()
    print("forma: {0}, min: {1}, max: {2}".format(temp_im.shape,
                                                 temp_im.min(),
                                                 temp_im.max()))
# Out:
# forma: (30, 30, 3), min: 0.03967320261437906, max: 0.9466503267973843
# forma: (30, 30, 3), min: 0.06460784313725489, max: 0.8903594771241827
# forma: (30, 30, 3), min: 0.08627450980392157, max: 0.9921568627450981
# forma: (30, 30, 3), min: 0.13725490196078433, max: 0.8453050108932467
# forma: (30, 30, 3), min: 0.056457516339869396, max: 0.996078431372549
# forma: (30, 30, 3), min: 0.050980392156862744, max: 0.9921568627450981

# %% [markdown]
# # opcional reducir RGB a Gray

# %%
from skimage.color import rgb2gray

images30 = np.array(images30)
images30 = rgb2gray(images30)

# %%
rand_images = random.sample(range(0, len(labels)), 6)
rand_images

for i in range(len(rand_images)):
    temp_im=images30[rand_images[i]]
    plt.subplot(1,len(rand_images),i+1)
    plt.axis("off")
    plt.imshow(images30[rand_images[i]],cmap="gray")
    plt.show()
    print("forma: {0}, min: {1}, max: {2}".format(temp_im.shape,
                                                 temp_im.min(),
                                                 temp_im.max()))
# Out:
# forma: (30, 30), min: 0.07926520261437886, max: 0.9951845751633988
# forma: (30, 30), min: 0.1693505045751635, max: 0.8307423058823528
# forma: (30, 30), min: 0.17763159150326766, max: 0.902285816993464
# forma: (30, 30), min: 0.10312849673202625, max: 0.9891580827886715
# forma: (30, 30), min: 0.0, max: 0.8595589875816995
# forma: (30, 30), min: 0.0, max: 0.9912867647058824

# %% [markdown]
# # NN

# %%
x = tf.placeholder(dtype=tf.float32,shape= [None, 30,30])
y = tf.placeholder(dtype=tf.int32, shape=[None])

images_flat = tf.contrib.layers.flatten(x)
logits = tf.contrib.layers.fully_connected(images_flat, 62, tf.nn.relu) #62 categorías a clasificar

loss = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(labels = y, logits = logits))

train_opt = tf.train.AdamOptimizer(learning_rate=0.001).minimize(loss)

final_pred = tf.arg_max(logits, 1)

accuracy = tf.reduce_mean(tf.cast(final_pred, tf.float32))

# %%
images_flat
# Out:
# <tf.Tensor 'Flatten/flatten/Reshape:0' shape=(?, 900) dtype=float32>

# %%
logits
# Out:
# <tf.Tensor 'fully_connected/Relu:0' shape=(?, 62) dtype=float32>

# %%
final_pred
# Out:
# <tf.Tensor 'ArgMax:0' shape=(?,) dtype=int64>

# %%
tf.set_random_seed(1234)
sess = tf.Session()

sess.run(tf.global_variables_initializer())

for i in range(400):
    #print("EPOCH: ", i)
    
    _,accuracy_val= sess.run([train_opt, accuracy],
                             feed_dict= {
                                 x:images30,
                                 y:list(labels)
                             })
    
    _,loss_val= sess.run([train_opt, loss],
                             feed_dict= {
                                 x:images30,
                                 y:list(labels)
                             })
    if i%10 == 0:
        print("EPOCH: ", i)
        print("accuracy: {0}, loss: {1}".format(accuracy_val, loss_val))
        
    #print("end EPOCH: ", i)
# Out:
# EPOCH:  0
# accuracy: 37.36262130737305, loss: 4.090119361877441
# EPOCH:  10
# accuracy: 36.895957946777344, loss: 3.500495195388794
# EPOCH:  20
# accuracy: 38.535301208496094, loss: 3.1593430042266846
# EPOCH:  30
# accuracy: 38.703826904296875, loss: 2.931297779083252
# EPOCH:  40
# accuracy: 38.34579086303711, loss: 2.776238203048706
# EPOCH:  50
# accuracy: 38.088741302490234, loss: 2.6646437644958496
# EPOCH:  60
# accuracy: 37.84961700439453, loss: 2.579447031021118
# EPOCH:  70
# accuracy: 37.71147537231445, loss: 2.511418581008911
# EPOCH:  80
# accuracy: 37.519126892089844, loss: 2.4551360607147217
# EPOCH:  90
# accuracy: 37.375736236572266, loss: 2.407686233520508
# EPOCH:  100
# accuracy: 37.24896240234375, loss: 2.3670430183410645
# EPOCH:  110
# accuracy: 37.04131317138672, loss: 2.3316285610198975
# EPOCH:  120
# accuracy: 36.88065719604492, loss: 2.300356388092041
# EPOCH:  130
# accuracy: 36.73420715332031, loss: 2.2724523544311523
# EPOCH:  140
# ...
